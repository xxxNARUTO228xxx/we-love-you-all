# %%
from ultralytics import YOLO

model = YOLO("./yolov8s.pt")

res = model.train(data="",epochs=40,batch=1,workers=19,patience=15,seed=42,imgsz=1024)
# Out:
# New https://pypi.org/project/ultralytics/8.0.208 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.181 🚀 Python-3.10.12 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24245MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("./yolov8m.pt")

res = model.predict(source="",save_txt=True,classes=0)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/3089 /media/storonkin/Work/projects/we-love-you-all/notebooks/images/no_weapon/119.VC7.15.40 Горького, 1Д 2023-09-16 20-00-00_000+0300 0s]-00000.png: 384x640 16 persons, 47.5ms
# image 2/3089 /media/storonkin/Work/projects/we-love-you-all/notebooks/images/no_weapon/119.VC7.15.40 Горького, 1Д 2023-09-16 20-00-00_000+0300 0s]-00001.png: 384x640 18 persons, 4.7ms
# ...
