# %% [markdown]
# ## ⚡ Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sat Nov  4 15:50:37 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.06              Driver Version: 545.23.06    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3090 Ti     On  | 00000000:01:00.0  On |                  Off |
# | 53%   50C    P8              28W / 480W |    364MiB / 24564MiB |     16%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      1428      G   /usr/lib/xorg/Xorg                          280MiB |
# |    0   N/A  N/A      1634      G   /usr/bin/gnome-shell                         58MiB |
# |    0   N/A  N/A     57899      G   ...ures=SpareRendererForSitePerProcess       11MiB |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## 🧪 Install autodistill
#
# **NOTE:** Autodistill is an ecosystem for using big, slower foundation models to train small, faster supervised models. Each Base, as well as the Target model, has its own separate repository and pip package.

# %%
# !pip install -q \
autodistill \
autodistill-grounded-sam \
autodistill-yolov8 \
roboflow \
supervision==0.9.0
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /media/storonkin/Work/projects/we-love-you-all/notebooks

# %% [markdown]
# ## 🖼️ Image dataset preperation
#
# **NOTE:** To use Autodistill all you need to have is a folder of images that you want to automatically annotate, and use for target model training.

# %%
# !mkdir {HOME}/images
# Out:
# mkdir: cannot create directory ‘/media/storonkin/Work/projects/we-love-you-all/notebooks/images’: File exists

# %% [markdown]
# Once you have downloaded your dataset, move all of the images from the `train` set in your downloaded dataset into the `images/` directory we created earlier:

# %%
# %mv {HOME}/<dataset-name>/train/* {HOME}/images

# %% [markdown]
# Now we are ready to start using Autodistill!

# %% [markdown]
# ### Download raw videos
#
# **NOTE:** In this tutorial, we will start with a directory containing video files and I will show you how to turn it into a ready-to-use collection of images. If you are working with your images, you can skip this part.

# %% [markdown]
# ### Convert videos into images
#
# **NOTE:** Now, let's convert videos into images. By default, the code below saves every `10th` frame from each video. You can change this by manipulating the value of the `FRAME_STRIDE` parameter.

# %%
HOME = os.getcwd()
VIDEO_DIR_PATH = f"{HOME}/train/train/weapon"
IMAGE_DIR_PATH = f"{HOME}/images/weapon"

DATASET_DIR_PATH = f"{HOME}/train/train/weapon_dataset1"
FRAME_STRIDE = 15

# %% [markdown]
#  **NOTE:** Notice that we put two of our videos aside so that we can use them at the end of the notebook to evaluate our model.

# %%
import supervision as sv

image_paths = sv.list_files_with_extensions(
    directory=IMAGE_DIR_PATH,
    extensions=["png", "jpg", "jpg"])

print('image count:', len(image_paths))
# Out:
# image count: 3310

# %% [markdown]
# **NOTE:** We can also plot sample of our image dataset.

# %%
# IMAGE_DIR_PATH = f"{HOME}/images"
SAMPLE_SIZE = 16
SAMPLE_GRID_SIZE = (4, 4)
SAMPLE_PLOT_SIZE = (16, 16)

# %%
import cv2
import supervision as sv

titles = [
    image_path.stem
    for image_path
    in image_paths[:SAMPLE_SIZE]]
images = [
    cv2.imread(str(image_path))
    for image_path
    in image_paths[:SAMPLE_SIZE]]

sv.plot_images_grid(images=images, titles=titles, grid_size=SAMPLE_GRID_SIZE, size=SAMPLE_PLOT_SIZE)

# %% [markdown]
# ## 🏷️ Autolabel dataset

# %% [markdown]
# ### Define ontology
#
# **Ontology** - an Ontology defines how your Base Model is prompted, what your Dataset will describe, and what your Target Model will predict. A simple Ontology is the CaptionOntology which prompts a Base Model with text captions and maps them to class names. Other Ontologies may, for instance, use a CLIP vector or example images instead of a text caption.

# %%
from autodistill.detection import CaptionOntology

ontology=CaptionOntology({
    
    "person , bandit , children , woman ,  man , gunman , shooterman": "person",
    # "bandit": "person",
    # "children": "person",
    # "woman": "person",
    # "man": "person",
    # "gunman": "person",
    # "shooterman": "person",
    
    "weapon , cold weapon , firearms , riffle , pistol , gun , shotgun , knife": "weapon",
    # "cold weapon": "weapon",
    # "firearms": "weapon",
    # "riffle": "weapon",
    # "pistol": "weapon",
    # "gun": "weapon",
    # "shotgun": "weapon",
    # "knife": "weapon"
})

# %% [markdown]
# ### Initiate base model and autolabel
#
# **Base Model** - A Base Model is a large foundation model that knows a lot about a lot. Base models are often multimodal and can perform many tasks. They're large, slow, and expensive. Examples of Base Models are GroundedSAM and GPT-4's upcoming multimodal variant. We use a Base Model (along with unlabeled input data and an Ontology) to create a Dataset.

# %%
from autodistill_grounded_sam import GroundedSAM

base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH,
    extension=".png",
    output_folder=DATASET_DIR_PATH)
# Out:
# trying to load grounding dino directly
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# final text_encoder_type: bert-base-uncased
# Labeling /media/storonkin/Work/projects/we-love-you-all/notebooks/images/weapon/frfr-00720.png:   0%|          | 0/3310 [00:00<?, ?it/s]The `device` argument is deprecated and will be removed in v5 of Transformers.
# torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
# None of the inputs have requires_grad=True. Gradients will be None
# Labeling /media/storonkin/Work/projects/we-love-you-all/notebooks/images/weapon/frfr-00718.png: 100%|██████████| 3310/3310 [43:54<00:00,  1.26it/s]
# Labeled dataset created - ready for distillation.

# %% [markdown]
# ### Display dataset sample
#
# **Dataset** - a Dataset is a set of auto-labeled data that can be used to train a Target Model. It is the output generated by a Base Model.

# %%
ANNOTATIONS_DIRECTORY_PATH = f"{HOME}/train/train/weapon_dataset1/labels"
IMAGES_DIRECTORY_PATH = f"{HOME}/train/train/weapon_dataset1/images"
DATA_YAML_PATH = f"{HOME}/train/train/weapon_dataset1/data.yaml"

# %%
import supervision as sv

dataset = sv.DetectionDataset.from_yolo(
    images_directory_path=IMAGES_DIRECTORY_PATH,
    annotations_directory_path=ANNOTATIONS_DIRECTORY_PATH,
    data_yaml_path=DATA_YAML_PATH)

len(dataset)

# %%
import supervision as sv

image_names = list(dataset.images.keys())[:SAMPLE_SIZE]

mask_annotator = sv.MaskAnnotator()
box_annotator = sv.BoxAnnotator()

images = []
for image_name in image_names:
    image = dataset.images[image_name]
    annotations = dataset.annotations[image_name]
    labels = [
        dataset.classes[class_id]
        for class_id
        in annotations.class_id]
    annotates_image = mask_annotator.annotate(
        scene=image.copy(),
        detections=annotations)
    annotates_image = box_annotator.annotate(
        scene=annotates_image,
        detections=annotations,
        labels=labels)
    images.append(annotates_image)

sv.plot_images_grid(
    images=images,
    titles=image_names,
    grid_size=SAMPLE_GRID_SIZE,
    size=SAMPLE_PLOT_SIZE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import supervision as sv
# ----> 3 image_names = list(dataset.images.keys())[:SAMPLE_SIZE]
#       5 box_annotator = sv.BoxAnnotator()
#       7 images = []
#
# NameError: name 'dataset' is not defined

# %% [markdown]
# ## 🔥 Train target model - YOLOv8
#
# **Target Model** - a Target Model is a supervised model that consumes a Dataset and outputs a distilled model that is ready for deployment. Target Models are usually small, fast, and fine-tuned to perform a specific task very well (but they don't generalize well beyond the information described in their Dataset). Examples of Target Models are YOLOv8 and DETR.

# %%
# %cd {HOME}

from autodistill_yolov8 import YOLOv8

target_model = YOLOv8("yolov8n.pt")
target_model.train(DATA_YAML_PATH, epochs=2)
# Out:
# /media/storonkin/Work/projects/we-love-you-all/notebooks
# WARNING ⚠️ Ultralytics settings reset to defaults. This is normal and may be due to a recent ultralytics package update, but may have overwritten previous settings.
# View and update settings with 'yolo settings' or at '/home/storonkin/.config/Ultralytics/settings.yaml'
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100%|██████████| 6.23M/6.23M [00:01<00:00, 3.66MB/s]
# New https://pypi.org/project/ultralytics/8.0.206 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24245MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/data.yaml, epochs=2, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/detect/train
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.Detect                [2, [64, 128, 256]]
# Model summary: 225 layers, 3011238 parameters, 3011222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias
# train: Scanning /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/labels... 2448 images, 403 backgrounds, 0 corrupt: 100%|██████████| 2448/2448 [00:01<00:00, 1852.71it/s]
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00002.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00003.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00004.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00005.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00006.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00007.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00010.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00011.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00012.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00014.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00015.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00082.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00084.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00085.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00086.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00087.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00088.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00089.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00090.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00092.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00095.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00096.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00097.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00098.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00099.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00100.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00101.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00102.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00103.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00106.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00108.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00109.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00110.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00111.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00113.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00114.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00118.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00119.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00120.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00121.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00126.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00129.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00130.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00132.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00133.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00136.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00137.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00138.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00140.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00141.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00143.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00144.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00145.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00146.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00148.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00149.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00150.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00174.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00175.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00176.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00177.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00179.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00180.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00181.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00183.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00185.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00186.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00187.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00188.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00189.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00190.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00191.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00192.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00193.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00194.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00196.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00198.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00294.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00295.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00296.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00299.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00301.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00302.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00303.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00304.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00305.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00306.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00307.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00480.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00481.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00482.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00483.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00484.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00485.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00487.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00488.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00489.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00490.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00491.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00492.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00493.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00495.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00497.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00506.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00507.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00509.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00510.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00512.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00515.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00516.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00518.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00523.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00524.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00529.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00532.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00533.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00534.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00535.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00536.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00537.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00538.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00539.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00540.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00541.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00542.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00543.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00544.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00545.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00548.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00549.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00550.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00657.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00719.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00720.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00721.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00723.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00724.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00725.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00727.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00728.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00729.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00730.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00731.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00733.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00734.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00735.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00736.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00737.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00738.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00739.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00741.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00742.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00743.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/60.VC8.2.3 Парковая 67 кафе 2023-11-03 15-30-00_000+0300 0s]-00744.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00128.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00172.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00173.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00174.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00175.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00176.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00179.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00180.jpg: 6 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00181.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00182.jpg: 6 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00183.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00184.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00185.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00186.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00187.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00189.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00190.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00191.jpg: 6 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00192.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00193.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00199.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00200.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00204.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00205.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00206.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00207.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00209.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00210.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00211.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00212.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00213.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00214.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00215.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00217.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00218.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00219.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00220.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00221.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00222.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00223.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00224.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00225.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00226.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00227.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/train/images/74.Шевченко 286 (Двор) 2023-10-23 13-00-00_000+0300 0s]-00229.jpg: 1 duplicate labels removed
# ...
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00516.jpg: 4 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00522.jpg: 3 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00524.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00528.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00532.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00534.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00537.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00543.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00547.jpg: 3 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00548.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00549.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00553.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00554.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00555.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00562.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00580.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00587.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00588.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00592.jpg: 3 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/74.Шевченко 286 (Двор) 2023-10-23 13-10-00_000+0300 0s]-00594.jpg: 3 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00006.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00007.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00020.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00022.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00023.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00032.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00035.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00073.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00077.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00109.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00156.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00171.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00174.jpg: 3 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00176.jpg: 4 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00177.jpg: 3 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00184.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00190.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00195.jpg: 4 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00216.jpg: 3 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00218.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00219.jpg: 3 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00220.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00224.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00233.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00242.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00243.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00266.jpg: 3 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00272.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00283.jpg: 3 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00284.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00289.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00303.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00306.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00322.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00341.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00342.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00356.jpg: 4 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00358.jpg: 4 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00362.jpg: 4 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00366.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00373.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00380.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00390.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00391.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00393.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00400.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00402.jpg: 3 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00403.jpg: 3 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00406.jpg: 4 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00407.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00408.jpg: 4 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00411.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00415.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00434.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00453.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00457.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00473.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00713.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00717.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00723.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00735.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/images/frfr-00748.jpg: 1 duplicate labels removed
# val: New cache created: /media/storonkin/Work/projects/we-love-you-all/notebooks/train/train/weapon_dataset/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 2 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/2       8.2G     0.7696      1.867      0.898         49        640: 100%|██████████| 153/153 [00:23<00:00,  6.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:03<00:00,  5.72it/s]
#                    all        613        892      0.835      0.853       0.87      0.743
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/2      5.47G     0.6348     0.9442     0.8504         56        640: 100%|██████████| 153/153 [00:20<00:00,  7.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:02<00:00,  8.07it/s]
#                    all        613        892      0.864      0.832      0.885      0.759
#
# 2 epochs completed in 0.014 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24245MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:02<00:00,  7.91it/s]
#                    all        613        892      0.864      0.832      0.885      0.758
#                 person        613        530       0.82      0.845      0.834      0.587
#                 weapon        613        362      0.908       0.82      0.936       0.93
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs/detect/train

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml		R_curve.png	       val_batch0_pred.jpg
# confusion_matrix.png	results.csv	       val_batch1_labels.jpg
# F1_curve.png		results.png	       val_batch1_pred.jpg
# labels_correlogram.jpg	train_batch0.jpg       val_batch2_labels.jpg
# labels.jpg		train_batch1.jpg       val_batch2_pred.jpg
# P_curve.png		train_batch2.jpg       weights
# PR_curve.png		val_batch0_labels.jpg

# %% [markdown]
# ## ⚖️ Evaluate target model
#
# **NOTE:** As with the regular YOLOv8 training, we can now take a look at artifacts stored in `runs` directory.

# %%
# %cd {HOME}

from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /media/storonkin/Work/projects/we-love-you-all/notebooks

# %%
# %cd {HOME}

from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /media/storonkin/Work/projects/we-love-you-all/notebooks

# %%
# %cd {HOME}

from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /media/storonkin/Work/projects/we-love-you-all/notebooks

# %% [markdown]
# ## 🎬 Run Inference on a video

# %%
INPUT_VIDEO_PATH = TEST_VIDEO_PATHS[0]
OUTPUT_VIDEO_PATH = f"{HOME}/output.mp4"
TRAINED_MODEL_PATH = f"{HOME}/runs/detect/train/weights/best.pt"

# %%
# !yolo predict model={TRAINED_MODEL_PATH} source={INPUT_VIDEO_PATH}

# %% [markdown]
# ## Upload dataset and model to Roboflow

# %% [markdown]
# comming soon...

# %% [markdown]
#   # 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
