# %% [markdown]
# Train yolov8

# %%
from ultralytics import YOLO
model = YOLO(model="/media/storonkin/Work/projects/we-love-you-all/notebooks/runs/detect/train2/weights/last.pt")

res = model.train(data="/media/storonkin/Work/datasets/hack_gun_clean/data.yaml",epochs=50,batch=1,imgsz=640,patience=10,save_period=4,workers=18,seed=42)
# Out:
# New https://pypi.org/project/ultralytics/8.0.208 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.181 🚀 Python-3.10.12 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24245MiB)
# ...

# %% [markdown]
# RT DETR

# %%
from ultralytics import RTDETR

# Load a COCO-pretrained RT-DETR-l model
model = RTDETR('/media/storonkin/Work/projects/we-love-you-all/notebooks/runs/detect/RTDETR-clean/weights/best.pt')

# Train the model on the COCO8 example dataset for 100 epochs
res = model.train(data="/media/storonkin/Work/datasets/hack_gun_all2/data.yaml",epochs=40,batch=4,imgsz=640,patience=10,workers=20)
# Out:
# New https://pypi.org/project/ultralytics/8.0.208 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.181 🚀 Python-3.10.12 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24245MiB)
# ...

# %% [markdown]
# ONLY GUN

# %%
from ultralytics import YOLO
model = YOLO(model="/media/storonkin/Work/projects/we-love-you-all/notebooks/runs/detect/yolovX-clean3/weights/best.pt")

res = model.train(data="/media/storonkin/Work/datasets/hack_gun_all2/data.yaml",epochs=30,batch=2,imgsz=640,patience=15,save_period=2,workers=20, classes=1)
# Out:
# New https://pypi.org/project/ultralytics/8.0.207 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.181 🚀 Python-3.10.12 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24245MiB)
# ...

# %% [markdown]
# RUN INFERENCE FOR CROP PERSON

# %%
from ultralytics import YOLO
model = YOLO(model="/media/storonkin/Work/projects/we-love-you-all/notebooks/runs/detect/train2/weights/last.pt")

model.predict("/media/storonkin/Work/projects/we-love-you-all/notebooks/images/no_weapon",save=True,classes=1,save_txt=True,conf=0.3)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/3089 /media/storonkin/Work/projects/we-love-you-all/notebooks/images/no_weapon/119.VC7.15.40 Горького, 1Д 2023-09-16 20-00-00_000+0300 0s]-00000.png: 384x640 (no detections), 15.1ms
# image 2/3089 /media/storonkin/Work/projects/we-love-you-all/notebooks/images/no_weapon/119.VC7.15.40 Горького, 1Д 2023-09-16 20-00-00_000+0300 0s]-00001.png: 384x640 (no detections), 14.0ms
# ...

# %% [markdown]
# SPLIT TASK ON 5 PERSON

# %%
import os
import shutil
from random import shuffle

# Путь к папке с изображениями
source_folder = ''

# Количество папок для создания
n_folders = 5

# Получить список всех изображений в папке
image_files = [f for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]

# Перемешать список изображений
shuffle(image_files)

# Равномерно распределить изображения по папкам
images_per_folder = len(image_files) // n_folders
remainder = len(image_files) % n_folders

# Создать N папок и распределить изображения
for i in range(n_folders):
    # Определить имя новой папки
    new_folder_name = os.path.join(source_folder, f'person_{i+1}')
    
    # Создать новую папку, если она еще не существует
    os.makedirs(new_folder_name, exist_ok=True)
    
    # Определить, сколько изображений должно быть скопировано в эту папку
    images_to_copy = image_files[i*images_per_folder : (i+1)*images_per_folder + (1 if i < remainder else 0)]
    
    # Копировать изображения в новую папку
    for img in images_to_copy:
        shutil.copy2(os.path.join(source_folder, img), new_folder_name)

print("Изображения были успешно распределены.")
# Out:
# Изображения были успешно распределены.
